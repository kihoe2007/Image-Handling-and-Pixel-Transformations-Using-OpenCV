# %% [raw]
# Step1:
# Load an image from your local directory and display it.

# %%
#Name: Kishore S M
#Reg No : 212224230131
#experiment no :Image-Handling-and Pixel Transformations Using OpenCV

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Read the image using OpenCV
img = cv2.imread('KISHORE.jpg', cv2.IMREAD_COLOR)

# %%
# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Display the image using Matplotlib
plt.imshow(img_rgb, cmap='viridis')  # You can change 'viridis' to another cmap or use None for RGB images
plt.title("Original Image")
plt.axis('off')  # Removes axis ticks and labels
plt.show()

# %% [raw]
# Step2:
# o Draw a line from the top-left to the bottom-right of the image.
#
# o Draw a circle at the center of the image.
#
# o Draw a rectangle around a specific region of interest in the image.
#
# o Add the text "OpenCV Drawing" at the top-left corner of the image.

# %% [raw]
# Draw a line from the top-left to the bottom-right of the image

# %%
crop = img_rgb[0:600,200:550] 
plt.imshow(crop[:,:,::-1])
plt.title("Cropped Region")
plt.axis("off")
plt.show()
crop.shape
# Out:
# (480, 350, 3)

# %%
# Load the image
image = cv2.imread('KISHORE.jpg') 
img = cv2.imread('KISHORE.png',image)

# %%
# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (480, 640, 3)

# %%
# Draw a line from top-left to bottom-right
line_img = cv2.line(img_rgb, (0, 0), (768, 600), (255, 0, 0), 2) # cv2.line(image, start_point, end_point, color, thickness)

# %%
plt.imshow(line_img, cmap='viridis')  
plt.title("Image with Line")
plt.axis('off')  
plt.show()

# %% [raw]
# Draw a circle at the center of the image.

# %%
# Load the image
image = cv2.imread('KISHORE.jpg') 

# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (480, 640, 3)

# %%
circle_img = cv2.circle(img_rgb,(400,300),150,(255,0,0),10) # cv2.circle(image, center, radius, color, thickness)

# %%
plt.imshow(circle_img, cmap='viridis')  
plt.title("Image with Circle")
plt.axis('off')  
plt.show()

# %% [raw]
# Draw a rectangle around  the whole image

# %%
# Load the image
image = cv2.imread('KISHORE.jpg') 

# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
# Draw a rectangle around the Whole image
rectangle_img = cv2.rectangle(img_rgb, (0, 0), (768, 600), (0, 0, 255), 10)  # cv2.rectangle(image, start_point, end_point, color, thickness)

# %%
plt.imshow(rectangle_img, cmap='viridis')  
plt.title("Image with Rectangle")
plt.axis('off')  
plt.show()

# %% [raw]
# Add the text "OpenCV Drawing" at the top-left corner of the image.

# %%
# Load the image
image = cv2.imread('KISHORE.jpg') 

# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Add text to the image
text_img = cv2.putText(img_rgb, "KISHORE", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (155, 155, 150), 10)  ## cv2.putText(image, text, position, font, font_scale, color, thickness)

# %%
plt.imshow(text_img, cmap='viridis')  
plt.title("Image with Text")
plt.axis('off')  
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1), plt.imshow(img), plt.title("Original Image"), plt.axis("off")
plt.show()

# %% [raw]
# Step3:
# o Convert the image from RGB to HSV and display it.
#
# o Convert the image from RGB to GRAY and display it.
#
# o Convert the image from RGB to YCrCb and display it.
#
# o Convert the HSV image back to RGB and display it.

# %%
# Load the image
image = cv2.imread('KISHORE.jpg')

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Original RGB Image
plt.imshow(image_rgb)
plt.title("Original RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
# Convert RGB to HSV
image_hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# %%
# HSV Image
plt.imshow(image_hsv)
plt.title("HSV Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
import numpy as np
merged_hsv = cv2.cvtColor(img, cv2.COLOR_HSV2RGB)
combined = np.concatenate((img_rgb, merged_hsv), axis=1)
plt.figure(figsize=(10, 5))
plt.imshow(combined)
plt.title("Original Image  &  Merged HSV Image")
plt.axis("off")
plt.show()

# %%
# Convert RGB to GRAY
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
# Grayscale Image
plt.imshow(image_gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
# Convert RGB to YCrCb
image_ycrcb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2YCrCb)

# %%
# YCrCb Image
plt.imshow(image_ycrcb)
plt.title("YCrCb Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
# Convert HSV back to RGB
image_hsv_to_rgb = cv2.cvtColor(image_hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(image_hsv_to_rgb)
plt.title("HSV to RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %% [raw]
# Step4:
# o Access and print the value of the pixel at coordinates (100, 100).
#
# o Modify the color of the pixel at (200, 200) to white.

# %%
# Modify a block of pixels (300x300) to white, starting from (200, 200)
image[200:500, 200:500] = [255, 255, 255]  # Rows: 200-499, Columns: 200-499

# %%
# Convert BGR to RGB for displaying with Matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Display the modified image
plt.imshow(image_rgb)
plt.title("Image with 300x300 White Block")
plt.axis("off")
plt.show()

# %% [raw]
# Step5:
# o Resize the original image to half its size and display it.

# %%
# Load the image
image = cv2.imread('KISHORE.jpg')

# %%
image.shape
# Out:
# (480, 640, 3)

# %%
# Resize the image to half its size
resized_image = cv2.resize(image, (1600// 2, 1200 // 2))  # (new_width, new_height)

# %%
# Convert BGR to RGB for displaying with Matplotlib
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)

# %%
resized_image_rgb.shape
# Out:
# (600, 800, 3)

# %%
# Display the resized image
plt.imshow(resized_image_rgb)
plt.title("Resized Image (Half Size)")
plt.axis("off")
plt.show()

# %% [raw]
# Step6:
# o Crop a region of interest (ROI) from the image (e.g., a 100x100 pixel area starting at (50, 50)) and display it.

# %%
# Load the image
image = cv2.imread('KISHORE.jpg')

# %%
image.shape
# Out:
# (480, 640, 3)

# %%
# Crop a 300x300 region starting from (50, 50)
roi = image[50:350, 50:350]  # Rows: 50-349, Columns: 50-349

# %%
# Convert BGR to RGB for displaying with Matplotlib
roi_rgb = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

# %%
# Display the cropped region (ROI)
plt.imshow(roi_rgb)
plt.title("Cropped Region of Interest (ROI)")
plt.axis("off")
plt.show()

# %% [raw]
# Step7:
# o Flip the original image horizontally and display it.
#
# o Flip the original image vertically and display it.

# %%
# Load the image
image = cv2.imread('KISHORE.jpg')

# %%
# Flip the image horizontally (left-right)
flipped_horizontally = cv2.flip(image, 1)

# %%
# Convert BGR to RGB for displaying with Matplotlib
flipped_horizontally_rgb= cv2.cvtColor(flipped_horizontally, cv2.COLOR_BGR2RGB)

# %%
# Horizontal flip
plt.imshow(flipped_horizontally_rgb)
plt.title("Flipped Horizontally")
plt.axis("off")

# %%
# Flip the image vertically (up-down)
flipped_vertically = cv2.flip(image, 0)

# %%
# Convert BGR to RGB for displaying with Matplotlib
flipped_vertically_rgb = cv2.cvtColor(flipped_vertically, cv2.COLOR_BGR2RGB)

# %%
# Vertical flip
plt.imshow(flipped_vertically_rgb)
plt.title("Flipped Vertically")
plt.axis("off")

# %% [raw]
# Step8:
# o Save the final modified image to your local directory.

# %%
crop = img_rgb[0:600,200:550] 
plt.imshow(crop[:,:,::-1])
plt.title("Cropped Region")
plt.axis("off")
plt.show()
crop.shape
# Out:
# (480, 350, 3)

# %%
img=cv2.imread('kishore.jpg',cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_rgb.shape
# Out:
# (480, 640, 3)

# %%
# Display the image using Matplotlib
plt.imshow(img_rgb, cmap='viridis')  # You can change 'viridis' to another cmap or use None for RGB images
plt.title("Original Image")
plt.axis('off')  # Removes axis ticks and labels
plt.show()

# %%
text = cv2.putText(img_rgb, "kishore", (300, 700),cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)  
plt.imshow(text, cmap='gray')  
plt.title("New image")
plt.show()

# %%
plt.title("Annotated image")
plt.imshow(img_rgb)
plt.show()

# %%
import numpy as np
n = np.ones(img_rgb.shape, dtype="uint8") * 50

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1), plt.imshow(img_rgb), plt.title("Original Image"), plt.axis("off")
plt.subplot(1,3,3), plt.imshow(img_darker), plt.title("Darker Image"), plt.axis("off")
plt.show()

# %%
import numpy as np

matrix1 = np.ones(img_rgb.shape, dtype="float32") * 1.1
matrix2 = np.ones(img_rgb.shape, dtype="float32") * 1.2
img_higher1 = cv2.multiply(img.astype("float32"), matrix1).clip(0,255).astype("uint8")
img_higher2 = cv2.multiply(img.astype("float32"), matrix2).clip(0,255).astype("uint8")

# %%
import cv2

# Read two images
img1 = cv2.imread("kishore.jpg")
img2 = cv2.imread("kishore.jpg")

# Generate third image using bitwise AND
third_img = cv2.bitwise_and(img1, img2)

# Save the result
cv2.imwrite("third_image.jpg", third_img)
# Out:
# True

# %%
print(img1.shape, img1.dtype)
print(img2.shape, img2.dtype)

# %%
import cv2

img1 = cv2.imread("kishore.jpg")
img2 = cv2.imread("kishore.jpg")  # note: space in filename

# Resize img2 to match img1
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Generate third image using bitwise AND
third_img = cv2.bitwise_and(img1, img2)

# Save result
cv2.imwrite("third_image.jpg", third_img)

# %%
cv2.imshow("Third Image", third_img)

cv2.waitKey(0)
cv2.destroyAllWindows()
